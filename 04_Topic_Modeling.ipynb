# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## Topic Modeling - Attempt #1 (All Text)

# %%
# Read in the document-term matrix
import pandas as pd

data_clean = pd.read_csv("lyrics_clean.csv",index_col=0)
data_clean
# Out:
#                                                             lyrics
# ABBA             ive love thought would manage hit ceiling stil...
# David_Bowie      small jean genie snuck city strung laser slash...
# Janis_Joplin     oh come come come come didnt make feel like ma...
# Michael_Jackson  butt mine gon na tell right show face broad da...
# Queen            dim light sing song full sad thing tango two s...
# Rolling_Stones   drag get old kid different today hear every mo...
# The_Clash        stay around dont play around old town seem lik...
# Bob_Dylan        go away window leave choose speed im one want ...
# Elton_John       hear distance sense far away old rudolph reind...
# Led_Zeppeling    hey thats right ask sweet mama let kid say mig...
# Pink_Floyd       distance ribbon black stretch point turn back ...
# Ramones          im lie bed night dont want grow nothing ever s...
# The_Beatles      jojo man think loner know couldnt last jojo le...
# The_Doors        lion street roam dog heat rabid foam beast cag...

# %% [markdown]
# ## LSA

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_clean.lyrics)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data_clean.index
data_dtm
# Out:
#                  aaaah  aaaahaaah  aaah  aah  aahah  aaow  abandon  abe  abel  \
# ABBA                 0          0     0    0      0     0        0    0     0
# David_Bowie          0          0     0    0      0     0        0    0     0
# Janis_Joplin         0          0     0    1      0     0        0    0     0
# Michael_Jackson      3          0     0    1      2     8        1    0     0
# Queen                0          0     0    7      0     0        1    0     0
# Rolling_Stones       0          0     0    0      0     0        0    0     0
# The_Clash            0          0     0    0      0     0        0    0     0
# Bob_Dylan            0          0     0    0      0     0        1    4     1
# Elton_John           0          0     0    0      0     0        0    0     0
# Led_Zeppeling        0          0     0    0      0     0        0    0     0
# Pink_Floyd           0          0     0    0      0     0        0    0     0
# Ramones              0          0     0    2      0     0        0    0     0
# The_Beatles          6          1     3    1      0     0        0    0     0
# The_Doors            0          0     0    0      0     0        0    0     0
#
#                  abide  ...  zombie  zombies  zone  zoo  zoomin  zuma  zwei  \
# ABBA                 2  ...       0        0     0    0       0     0     0
# David_Bowie          0  ...       0        0     0    0       0     0     0
# Janis_Joplin         0  ...       0        0     0    0       0     0     0
# Michael_Jackson      0  ...       0        0     0    0       0     0     0
# Queen                0  ...       0        0     0    2       0     0     0
# Rolling_Stones       0  ...       0        1     0    0       0     3     0
# The_Clash            0  ...       1        0     2    0       3     0     0
# Bob_Dylan            0  ...       0        0     0    0       0     0     0
# Elton_John           0  ...       0        0     3    0       0     0     0
# Led_Zeppeling        0  ...       0        0     0    0       0     0     0
# Pink_Floyd           0  ...       0        0     0    0       0     0     1
# Ramones              0  ...       0        0     0    0       0     0     0
# The_Beatles          0  ...       0        0     0    0       0     0     0
# The_Doors            0  ...       0        0     0    0       0     0     0
#
#                  élysées  über  überm
# ABBA                   1     0      0
# David_Bowie            0     0      0
# Janis_Joplin           0     0      0
# Michael_Jackson        0     1      1
# Queen                  0     0      0
# Rolling_Stones         0     0      0
# The_Clash              0     0      0
# Bob_Dylan              0     0      0
# Elton_John             0     0      0
# Led_Zeppeling          0     0      0
# Pink_Floyd             0     0      0
# Ramones                0     0      0
# The_Beatles            0     0      0
# The_Doors              0     0      0
#
# [14 rows x 7040 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(min_df=.2, max_df=.8)
tfidf = vectorizer.fit_transform(data_clean.lyrics)
len(vectorizer.get_feature_names())
# Out:
# 1600

# %%
data_tfidf = pd.DataFrame(tfidf.toarray(), columns=vectorizer.get_feature_names())
data_tfidf.index = data_clean.index
data_tfidf
# Out:
#                       aah   abandon      able     abuse    accept      ache  \
# ABBA             0.000000  0.000000  0.011586  0.000000  0.000000  0.000000
# David_Bowie      0.000000  0.000000  0.000000  0.000000  0.000000  0.005498
# Janis_Joplin     0.014723  0.000000  0.000000  0.000000  0.000000  0.000000
# Michael_Jackson  0.006360  0.007706  0.006360  0.034827  0.000000  0.005405
# Queen            0.050746  0.008783  0.000000  0.007939  0.000000  0.018483
# Rolling_Stones   0.000000  0.000000  0.000000  0.012537  0.000000  0.009729
# The_Clash        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Bob_Dylan        0.000000  0.009912  0.008181  0.000000  0.019824  0.020859
# Elton_John       0.000000  0.000000  0.000000  0.000000  0.000000  0.023119
# Led_Zeppeling    0.000000  0.000000  0.000000  0.024803  0.000000  0.009624
# Pink_Floyd       0.000000  0.000000  0.017437  0.000000  0.021127  0.000000
# Ramones          0.017512  0.000000  0.000000  0.000000  0.042436  0.000000
# The_Beatles      0.009817  0.000000  0.009817  0.000000  0.000000  0.000000
# The_Doors        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                       act    action    advice    affair  ...      writ  \
# ABBA             0.000000  0.010654  0.000000  0.046345  ...  0.000000
# David_Bowie      0.005948  0.005948  0.000000  0.006469  ...  0.015675
# Janis_Joplin     0.000000  0.000000  0.000000  0.000000  ...  0.000000
# Michael_Jackson  0.011697  0.000000  0.007706  0.000000  ...  0.000000
# Queen            0.006666  0.006666  0.000000  0.000000  ...  0.000000
# Rolling_Stones   0.000000  0.000000  0.000000  0.011448  ...  0.000000
# The_Clash        0.000000  0.000000  0.009363  0.000000  ...  0.009363
# Bob_Dylan        0.022569  0.000000  0.009912  0.008181  ...  0.000000
# Elton_John       0.016676  0.025014  0.000000  0.018135  ...  0.000000
# Led_Zeppeling    0.000000  0.000000  0.000000  0.000000  ...  0.013720
# Pink_Floyd       0.000000  0.016035  0.000000  0.000000  ...  0.000000
# Ramones          0.000000  0.016104  0.000000  0.000000  ...  0.000000
# The_Beatles      0.009028  0.000000  0.000000  0.000000  ...  0.000000
# The_Doors        0.000000  0.000000  0.000000  0.000000  ...  0.000000
#
#                     write        ya      yawn    yellow  yesterday       yet  \
# ABBA             0.007921  0.007395  0.014038  0.000000   0.000000  0.042616
# David_Bowie      0.022113  0.016515  0.007837  0.000000   0.004423  0.000000
# Janis_Joplin     0.000000  0.000000  0.000000  0.000000   0.010066  0.000000
# Michael_Jackson  0.000000  0.012179  0.007706  0.005014   0.008697  0.000000
# Queen            0.019826  0.000000  0.000000  0.005716   0.004956  0.026665
# Rolling_Stones   0.000000  0.014614  0.000000  0.009026   0.015653  0.000000
# The_Clash        0.005283  0.271284  0.000000  0.006093   0.000000  0.000000
# Bob_Dylan        0.033560  0.172323  0.000000  0.006450   0.016780  0.030092
# Elton_John       0.024797  0.046301  0.000000  0.057191   0.000000  0.025014
# Led_Zeppeling    0.007742  0.007228  0.000000  0.008928   0.015484  0.010413
# Pink_Floyd       0.011922  0.077910  0.000000  0.000000   0.011922  0.000000
# Ramones          0.000000  0.000000  0.000000  0.000000   0.005987  0.000000
# The_Beatles      0.013424  0.006266  0.000000  0.216722   0.080544  0.000000
# The_Doors        0.008528  0.079614  0.000000  0.000000   0.000000  0.011470
#
#                        yo      york     youth
# ABBA             0.014038  0.000000  0.000000
# David_Bowie      0.000000  0.012937  0.006469
# Janis_Joplin     0.000000  0.000000  0.000000
# Michael_Jackson  0.007706  0.000000  0.000000
# Queen            0.000000  0.000000  0.021748
# Rolling_Stones   0.000000  0.011448  0.011448
# The_Clash        0.131078  0.023183  0.023183
# Bob_Dylan        0.000000  0.008181  0.000000
# Elton_John       0.000000  0.045337  0.000000
# Led_Zeppeling    0.000000  0.000000  0.011324
# Pink_Floyd       0.000000  0.000000  0.000000
# Ramones          0.000000  0.000000  0.000000
# The_Beatles      0.000000  0.000000  0.000000
# The_Doors        0.000000  0.000000  0.000000
#
# [14 rows x 1600 columns]

# %%
from sklearn.decomposition import TruncatedSVD

# SVD represent documents and terms in vectors 
svd_model = TruncatedSVD(n_components=5)

svd_model.fit(data_tfidf)

print(svd_model.components_.shape)
print(svd_model.singular_values_)
# Out:
# (5, 1600)
# [1.91038837 1.24003497 0.9946658  0.95895778 0.94696619]

# %%
terms = vectorizer.get_feature_names()

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x:x[1], reverse=True)[:7]
    print("Topic "+str(i)+": ")
    for t in sorted_terms:
        print("%.2f*%s "% (t[1], t[0]) ,end='')
    print("")
# Out:
# Topic 0:
# 0.35*la 0.24*ah 0.17*babe 0.11*put 0.11*roll 0.10*ya 0.10*ta
# Topic 1:
# 0.73*la 0.16*whoa 0.16*da 0.12*american 0.10*babe 0.09*fame 0.09*woah
# Topic 2:
# 0.61*bird 0.19*family 0.16*glue 0.14*poison 0.13*beach 0.13*smart 0.13*roll
# Topic 3:
# 0.30*kiss 0.27*bird 0.25*doodoo 0.25*gim 0.17*wasnt 0.10*number 0.10*teacher
# Topic 4:
# 0.69*number 0.20*yellow 0.18*bang 0.17*shoot 0.11*diamond 0.10*ha 0.09*lala

# %%
#import sys
#!conda install --yes --prefix {sys.prefix} umap-learn

# %% [markdown]
# ## LDA

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english',min_df=.1, max_df=.7)
data_cv = cv.fit_transform(data_clean.lyrics)
data = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data.index = data_clean.index
data
# Out:
#                  aaaah  aah  abandon  able  aboard  abraham  absolutely  \
# ABBA                 0    0        0     1       0        0           0
# David_Bowie          0    0        0     0       0        0           0
# Janis_Joplin         0    1        0     0       0        0           0
# Michael_Jackson      3    1        1     1       0        1           0
# Queen                0    7        1     0       0        0           1
# Rolling_Stones       0    0        0     0       0        0           0
# The_Clash            0    0        0     0       0        0           0
# Bob_Dylan            0    0        1     1       0        1           0
# Elton_John           0    0        0     0       2        0           0
# Led_Zeppeling        0    0        0     0       0        0           0
# Pink_Floyd           0    0        0     1       0        0           2
# Ramones              0    2        0     0       0        0           0
# The_Beatles          6    1        0     1       1        0           0
# The_Doors            0    0        0     0       0        0           0
#
#                  abuse  abused  accept  ...  writer  yard  yawn  yearn  yell  \
# ABBA                 0       0       0  ...       0     0     1      0     0
# David_Bowie          0       0       0  ...       0     0     1      0     1
# Janis_Joplin         0       0       0  ...       0     0     0      0     0
# Michael_Jackson      5       0       0  ...       0     0     1      1     0
# Queen                1       0       0  ...       0     0     0      0     0
# Rolling_Stones       1       0       0  ...       0     0     0      0     0
# The_Clash            0       0       0  ...       0     0     0      0     0
# Bob_Dylan            0       0       2  ...       1     0     0      0     0
# Elton_John           0       1       0  ...       0     0     0      0     0
# Led_Zeppeling        2       0       0  ...       0     0     0      1     0
# Pink_Floyd           0       1       1  ...       0     0     0      0     1
# Ramones              0       0       4  ...       0     0     0      0     0
# The_Beatles          0       0       0  ...       0     2     0      0     0
# The_Doors            0       0       0  ...       1     3     0      0     0
#
#                  yellow  yo  york  youth  zone
# ABBA                  0   1     0      0     0
# David_Bowie           0   0     2      1     0
# Janis_Joplin          0   0     0      0     0
# Michael_Jackson       1   1     0      0     0
# Queen                 1   0     0      3     0
# Rolling_Stones        1   0     1      1     0
# The_Clash             1  14     3      3     2
# Bob_Dylan             1   0     1      0     0
# Elton_John            8   0     5      0     3
# Led_Zeppeling         1   0     0      1     0
# Pink_Floyd            0   0     0      0     0
# Ramones               0   0     0      0     0
# The_Beatles          28   0     0      0     0
# The_Doors             0   0     0      0     0
#
# [14 rows x 2406 columns]

# %%
from gensim import matutils, models
import scipy.sparse

# %%
tdm = data.transpose()
tdm.head()
# Out:
#          ABBA  David_Bowie  Janis_Joplin  Michael_Jackson  Queen  \
# aaaah       0            0             0                3      0
# aah         0            0             1                1      7
# abandon     0            0             0                1      1
# able        1            0             0                1      0
# aboard      0            0             0                0      0
#
#          Rolling_Stones  The_Clash  Bob_Dylan  Elton_John  Led_Zeppeling  \
# aaaah                 0          0          0           0              0
# aah                   0          0          0           0              0
# abandon               0          0          1           0              0
# able                  0          0          1           0              0
# aboard                0          0          0           2              0
#
#          Pink_Floyd  Ramones  The_Beatles  The_Doors
# aaaah             0        0            6          0
# aah               0        2            1          0
# abandon           0        0            0          0
# able              1        0            1          0
# aboard            0        0            1          0

# %%
# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
id2word = dict((v, k) for k, v in cv.vocabulary_.items())

# %%
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term),
# we need to specify two other parameters as well - the number of topics and the number of passes
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2)
lda.print_topics()
# Out:
# [(0,
#   '0.018*"la" + 0.006*"number" + 0.006*"bird" + 0.004*"radio" + 0.004*"whoa" + 0.004*"law" + 0.004*"til" + 0.004*"ta" + 0.003*"family" + 0.003*"theyll"'),
#  (1,
#   '0.010*"la" + 0.006*"bird" + 0.005*"number" + 0.005*"ta" + 0.004*"white" + 0.004*"okay" + 0.003*"bitch" + 0.003*"fame" + 0.003*"rhythm" + 0.003*"saturday"')]

# %%
# LDA for num_topics = 3
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3)
lda.print_topics()
# Out:
# [(0,
#   '0.025*"la" + 0.006*"fame" + 0.006*"american" + 0.005*"whoa" + 0.005*"ta" + 0.004*"da" + 0.004*"modern" + 0.004*"afraid" + 0.004*"diamond" + 0.004*"white"'),
#  (1,
#   '0.011*"la" + 0.010*"number" + 0.005*"okay" + 0.005*"ta" + 0.004*"til" + 0.004*"bird" + 0.004*"rhythm" + 0.004*"radio" + 0.004*"annie" + 0.003*"white"'),
#  (2,
#   '0.010*"bird" + 0.008*"la" + 0.005*"law" + 0.005*"theyll" + 0.004*"number" + 0.004*"family" + 0.004*"white" + 0.003*"ta" + 0.003*"gim" + 0.003*"shoot"')]

# %%
# LDA for num_topics = 4
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4)
lda.print_topics()
# Out:
# [(0,
#   '0.017*"la" + 0.005*"number" + 0.004*"ta" + 0.004*"law" + 0.004*"radio" + 0.004*"bicycle" + 0.003*"shoot" + 0.003*"bout" + 0.003*"white" + 0.003*"magic"'),
#  (1,
#   '0.013*"bird" + 0.007*"number" + 0.006*"family" + 0.006*"okay" + 0.005*"rhythm" + 0.005*"annie" + 0.005*"la" + 0.005*"theyll" + 0.004*"ta" + 0.004*"til"'),
#  (2,
#   '0.019*"la" + 0.005*"ta" + 0.004*"da" + 0.004*"whoa" + 0.004*"fame" + 0.004*"number" + 0.003*"white" + 0.003*"american" + 0.003*"afraid" + 0.003*"til"'),
#  (3,
#   '0.016*"la" + 0.007*"number" + 0.006*"bird" + 0.005*"american" + 0.004*"fame" + 0.004*"whoa" + 0.004*"white" + 0.004*"diamond" + 0.003*"bitch" + 0.003*"da"')]

# %% [markdown]
# ## Topic Modeling - Attempt #2 (Nouns Only)

# %%
# Let's create a function to pull out nouns from a string of text
from nltk import word_tokenize, pos_tag

def nouns(text):
    '''Given a string of text, tokenize the text and pull out only the nouns.'''
    is_noun = lambda pos: pos[:2] == 'NN'
    tokenized = word_tokenize(text)
    all_nouns = [word for (word, pos) in pos_tag(tokenized) if is_noun(pos)] 
    return ' '.join(all_nouns)

# %%
# Read in the cleaned data, before the CountVectorizer step
import pandas as pd

data_clean = pd.read_csv("lyrics_clean.csv",index_col=0)
data_clean
# Out:
#                                                             lyrics
# ABBA             ive love thought would manage hit ceiling stil...
# David_Bowie      small jean genie snuck city strung laser slash...
# Janis_Joplin     oh come come come come didnt make feel like ma...
# Michael_Jackson  butt mine gon na tell right show face broad da...
# Queen            dim light sing song full sad thing tango two s...
# Rolling_Stones   drag get old kid different today hear every mo...
# The_Clash        stay around dont play around old town seem lik...
# Bob_Dylan        go away window leave choose speed im one want ...
# Elton_John       hear distance sense far away old rudolph reind...
# Led_Zeppeling    hey thats right ask sweet mama let kid say mig...
# Pink_Floyd       distance ribbon black stretch point turn back ...
# Ramones          im lie bed night dont want grow nothing ever s...
# The_Beatles      jojo man think loner know couldnt last jojo le...
# The_Doors        lion street roam dog heat rabid foam beast cag...

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns = pd.DataFrame(data_clean.lyrics.apply(nouns))
data_nouns
# Out:
#                                                             lyrics
# ABBA             love thought ceiling feeling dont think make d...
# David_Bowie      jean city strung laser slash eat razor pull wa...
# Janis_Joplin     didnt feel man yeah everything woman honey tim...
# Michael_Jackson  butt mine gon show face im tell gon mind shoot...
# Queen            dim light thing tango serenade heart valentino...
# Rolling_Stones   drag kid today mother need something today she...
# The_Clash        stay play town lotta people tonight lotta peop...
# Bob_Dylan        window speed babe im need youre someone whos d...
# Elton_John       distance sense rudolph reindeer santa head eas...
# Led_Zeppeling    hey thats mama kid keep hid baby see im rider ...
# Pink_Floyd       distance ribbon stretch point flight fancy win...
# Ramones          lie night dont grow nothing dont grow move wor...
# The_Beatles      jojo man couldnt jojo home tucson california g...
# The_Doors        lion street roam dog heat rabid foam beast hea...

# %%
# Create a new document-term matrix using only nouns
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Re-add the additional stop words since we are recreating the document-term matrix
add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people',
                  'youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said']
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate a document-term matrix with only nouns
cvn = CountVectorizer(stop_words=stop_words, min_df=.1, max_df=.9)
data_cvn = cvn.fit_transform(data_nouns.lyrics)
data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names())
data_dtmn.index = data_nouns.index
data_dtmn
# Out:
#                  aaaah  aah  abuse  ace  ache  act  action  actor  \
# ABBA                 0    0      0    1     0    0       1      0
# David_Bowie          0    0      0    0     1    1       1      1
# Janis_Joplin         0    0      0    0     0    0       0      0
# Michael_Jackson      2    1      5    0     1    1       0      0
# Queen                0    4      0    0     2    1       1      0
# Rolling_Stones       0    0      0    0     1    0       0      0
# The_Clash            0    0      0    0     0    0       0      0
# Bob_Dylan            0    0      0    1     3    1       0      0
# Elton_John           0    0      0    0     3    2       3      0
# Led_Zeppeling        0    0      2    0     1    0       0      0
# Pink_Floyd           0    0      0    0     0    0       1      0
# Ramones              0    1      0    0     0    0       2      0
# The_Beatles          4    1      0    0     0    0       0      0
# The_Doors            0    0      0    0     0    0       0      2
#
#                  advertising  advice  ...  yawn  yell  yellow  yes  yesterday  \
# ABBA                       0       0  ...     0     0       0    7          0
# David_Bowie                0       0  ...     1     1       0    2          1
# Janis_Joplin               0       0  ...     0     0       0    4          1
# Michael_Jackson            0       1  ...     1     0       0    2          2
# Queen                      0       0  ...     0     0       1    9          1
# Rolling_Stones             0       0  ...     0     0       1   10          2
# The_Clash                  2       1  ...     0     0       0    4          0
# Bob_Dylan                  1       1  ...     0     0       0    9          3
# Elton_John                 0       0  ...     0     0       0    0          0
# Led_Zeppeling              0       0  ...     0     0       0    5          2
# Pink_Floyd                 0       0  ...     0     1       0    3          1
# Ramones                    0       0  ...     0     0       0    0          1
# The_Beatles                0       0  ...     0     0       0    5         12
# The_Doors                  0       0  ...     0     0       0    2          0
#
#                  yo  york  youd  youll  youth
# ABBA              1     0     0      4      0
# David_Bowie       0     2     0      2      0
# Janis_Joplin      0     0     0      0      0
# Michael_Jackson   0     0     1     13      0
# Queen             0     0     1      3      3
# Rolling_Stones    0     1     1      1      1
# The_Clash        12     1     0      4      3
# Bob_Dylan         0     1     4      5      0
# Elton_John        0     5     1      7      0
# Led_Zeppeling     0     0     0      0      0
# Pink_Floyd        0     0     1      9      0
# Ramones           0     0     0      2      0
# The_Beatles       0     0     0      1      0
# The_Doors         0     0     1      3      0
#
# [14 rows x 1764 columns]

# %%
# Create the gensim corpus
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))

# Create the vocabulary dictionary
id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
# Let's start with 2 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.027*"rock" + 0.021*"bird" + 0.019*"number" + 0.012*"honey" + 0.011*"wan" + 0.011*"law" + 0.010*"dance" + 0.008*"cause" + 0.008*"tonight" + 0.008*"babe"'),
#  (1,
#   '0.013*"aint" + 0.011*"cause" + 0.010*"ah" + 0.008*"ooh" + 0.006*"change" + 0.006*"dance" + 0.006*"place" + 0.006*"rock" + 0.005*"babe" + 0.005*"child"')]

# %%
# Let's try topics = 3
ldan = models.LdaModel(corpus=corpusn, num_topics=3, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.018*"number" + 0.009*"aint" + 0.009*"fame" + 0.009*"child" + 0.009*"diamond" + 0.008*"cause" + 0.007*"star" + 0.007*"wall" + 0.006*"shatter" + 0.006*"dance"'),
#  (1,
#   '0.024*"rock" + 0.015*"cause" + 0.014*"aint" + 0.013*"bird" + 0.012*"wan" + 0.010*"dance" + 0.010*"tonight" + 0.009*"stop" + 0.008*"change" + 0.008*"roll"'),
#  (2,
#   '0.012*"ah" + 0.011*"babe" + 0.011*"ooh" + 0.011*"honey" + 0.010*"somebody" + 0.009*"aint" + 0.008*"lord" + 0.006*"blow" + 0.006*"song" + 0.006*"whoa"')]

# %%
# Let's try 4 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn)
ldan.print_topics()
# Out:
# [(0,
#   '0.014*"aint" + 0.012*"rock" + 0.012*"cause" + 0.009*"ooh" + 0.009*"ah" + 0.007*"wan" + 0.006*"dance" + 0.006*"stop" + 0.006*"tonight" + 0.005*"god"'),
#  (1,
#   '0.017*"rock" + 0.012*"aint" + 0.010*"cause" + 0.010*"bird" + 0.009*"dance" + 0.009*"ah" + 0.007*"wan" + 0.007*"tonight" + 0.006*"babe" + 0.006*"change"'),
#  (2,
#   '0.012*"cause" + 0.010*"number" + 0.010*"aint" + 0.007*"rock" + 0.007*"child" + 0.006*"ah" + 0.006*"place" + 0.006*"babe" + 0.006*"change" + 0.005*"dance"'),
#  (3,
#   '0.014*"number" + 0.012*"honey" + 0.008*"babe" + 0.008*"lord" + 0.008*"rock" + 0.008*"ah" + 0.007*"ooh" + 0.007*"somebody" + 0.006*"aint" + 0.006*"dance"')]

# %% [markdown]
# ## Topic Modeling - Attempt #3 (Nouns and Adjectives)

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)] 
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean.lyrics.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                             lyrics
# ABBA             ive love thought ceiling strange old feeling d...
# David_Bowie      small jean genie snuck city strung laser slash...
# Janis_Joplin     come didnt feel man yeah everything woman hone...
# Michael_Jackson  butt mine gon show face broad daylight im tell...
# Queen            dim light song full sad thing tango serenade h...
# Rolling_Stones   drag old kid different today mother mother nee...
# The_Clash        stay dont play old town travel lotta people su...
# Bob_Dylan        window choose speed babe im need youre someone...
# Elton_John       hear distance sense old rudolph reindeer santa...
# Led_Zeppeling    hey thats sweet mama kid dont keep hid baby da...
# Pink_Floyd       distance ribbon black stretch point flight fan...
# Ramones          im lie night dont grow nothing right dont grow...
# The_Beatles      jojo man loner couldnt last jojo home tucson c...
# The_Doors        lion street roam dog heat rabid foam beast cag...

# %%
# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, min_df=.1, max_df=.7)
data_cvna = cvna.fit_transform(data_nouns_adj.lyrics)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#                  aaaah  aah  abandon  able  abraham  abuse  accept  ace  ache  \
# ABBA                 0    0        0     1        0      0       0    1     0
# David_Bowie          0    0        0     0        0      0       0    0     1
# Janis_Joplin         0    1        0     0        0      0       0    0     0
# Michael_Jackson      3    1        1     1        1      5       0    0     1
# Queen                0    5        1     0        0      0       0    0     2
# Rolling_Stones       0    0        0     0        0      0       0    0     1
# The_Clash            0    0        0     0        0      0       0    0     0
# Bob_Dylan            0    0        0     1        1      0       2    1     3
# Elton_John           0    0        0     0        0      0       0    0     3
# Led_Zeppeling        0    0        0     0        0      2       0    0     1
# Pink_Floyd           0    0        0     1        0      0       1    0     0
# Ramones              0    2        0     0        0      0       0    0     0
# The_Beatles          5    1        0     1        0      0       0    0     0
# The_Doors            0    0        0     0        0      0       0    0     0
#
#                  act  ...  writ  write  writer  yawn  yearn  yell  yellow  yo  \
# ABBA               0  ...     0      0       0     0      0     0       0   1
# David_Bowie        1  ...     2      5       0     1      0     1       0   0
# Janis_Joplin       0  ...     0      0       0     0      0     0       0   0
# Michael_Jackson    2  ...     0      0       0     1      1     0       0   1
# Queen              1  ...     0      4       0     0      0     0       1   0
# Rolling_Stones     0  ...     0      0       0     0      0     0       1   0
# The_Clash          0  ...     1      1       0     0      0     0       1  12
# Bob_Dylan          2  ...     0      4       1     0      0     0       1   0
# Elton_John         2  ...     0      2       0     0      0     0       8   0
# Led_Zeppeling      0  ...     1      0       0     0      1     0       1   0
# Pink_Floyd         0  ...     0      1       0     0      0     1       0   0
# Ramones            0  ...     0      0       0     0      0     0       0   0
# The_Beatles        0  ...     0      2       0     0      0     0      28   0
# The_Doors          0  ...     0      0       1     0      0     0       0   0
#
#                  york  youth
# ABBA                0      0
# David_Bowie         2      0
# Janis_Joplin        0      0
# Michael_Jackson     0      0
# Queen               0      3
# Rolling_Stones      1      1
# The_Clash           3      3
# Bob_Dylan           1      0
# Elton_John          5      0
# Led_Zeppeling       0      0
# Pink_Floyd          0      0
# Ramones             0      0
# The_Beatles         0      0
# The_Doors           0      0
#
# [14 rows x 2149 columns]

# %%
# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

# Create the vocabulary dictionary
id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
# Let's start with 2 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.012*"bird" + 0.006*"fame" + 0.006*"american" + 0.005*"bitch" + 0.005*"family" + 0.005*"afraid" + 0.005*"theyll" + 0.004*"modern" + 0.004*"white" + 0.004*"hello"'),
#  (1,
#   '0.011*"number" + 0.006*"law" + 0.006*"til" + 0.006*"ta" + 0.005*"whoa" + 0.005*"okay" + 0.005*"radio" + 0.004*"shoot" + 0.004*"gim" + 0.004*"white"')]

# %%
# Let's try 3 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna)
ldana.print_topics()
# Out:
# [(0,
#   '0.006*"ta" + 0.005*"radio" + 0.005*"bird" + 0.005*"til" + 0.004*"law" + 0.004*"family" + 0.004*"bitch" + 0.004*"white" + 0.003*"fame" + 0.003*"whoa"'),
#  (1,
#   '0.009*"bird" + 0.005*"white" + 0.005*"law" + 0.004*"ta" + 0.004*"shatter" + 0.004*"gim" + 0.003*"american" + 0.003*"gold" + 0.003*"theyll" + 0.003*"wonder"'),
#  (2,
#   '0.014*"number" + 0.005*"bird" + 0.005*"okay" + 0.004*"shoot" + 0.004*"til" + 0.004*"ta" + 0.004*"white" + 0.004*"whoa" + 0.003*"fame" + 0.003*"force"')]

# %%
# Let's try 4 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna)
ldana.print_topics()
# Out:
# [(0,
#   '0.007*"number" + 0.006*"bird" + 0.005*"white" + 0.004*"kiss" + 0.004*"gim" + 0.004*"american" + 0.004*"diamond" + 0.004*"family" + 0.004*"til" + 0.003*"fame"'),
#  (1,
#   '0.008*"number" + 0.005*"bird" + 0.005*"til" + 0.005*"ta" + 0.005*"okay" + 0.004*"whoa" + 0.004*"radio" + 0.003*"shatter" + 0.003*"family" + 0.003*"rhythm"'),
#  (2,
#   '0.012*"bird" + 0.008*"number" + 0.005*"radio" + 0.005*"shoot" + 0.004*"ta" + 0.004*"white" + 0.004*"family" + 0.004*"theyll" + 0.004*"law" + 0.004*"whoa"'),
#  (3,
#   '0.006*"ta" + 0.005*"fame" + 0.005*"law" + 0.005*"white" + 0.004*"american" + 0.004*"afraid" + 0.003*"number" + 0.003*"gold" + 0.003*"kiss" + 0.003*"ha"')]

# %% [markdown]
# ## Identify Topics in Each Document

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna)
ldana.print_topics()
# Out:
# [(0,
#   '0.006*"okay" + 0.006*"til" + 0.005*"bird" + 0.005*"whoa" + 0.005*"ta" + 0.005*"fame" + 0.005*"annie" + 0.005*"white" + 0.005*"rhythm" + 0.004*"force"'),
#  (1,
#   '0.012*"number" + 0.006*"bird" + 0.004*"american" + 0.004*"ta" + 0.004*"shoot" + 0.003*"key" + 0.003*"yellow" + 0.003*"gold" + 0.003*"radio" + 0.003*"diamond"'),
#  (2,
#   '0.005*"ta" + 0.004*"number" + 0.004*"wonder" + 0.004*"gim" + 0.003*"radio" + 0.003*"whoa" + 0.003*"bitch" + 0.003*"wasnt" + 0.003*"white" + 0.003*"freedom"'),
#  (3,
#   '0.014*"bird" + 0.008*"law" + 0.008*"number" + 0.006*"family" + 0.005*"white" + 0.005*"radio" + 0.004*"ta" + 0.004*"theyll" + 0.003*"beach" + 0.003*"jazz"')]

# %%
corpus_transformed = ldana[corpusna]
for i,j in enumerate(list(corpus_transformed)):
    print(data_dtmna.index[i],j)
# Out:
# ABBA [(2, 0.98860246)]
# David_Bowie [(0, 0.8348954), (1, 0.16478392)]
# Janis_Joplin [(0, 0.99695754)]
# Michael_Jackson [(0, 0.99957347)]
# Queen [(0, 0.5518313), (2, 0.44773147)]
# Rolling_Stones [(0, 0.9993766)]
# The_Clash [(3, 0.9995809)]
# Bob_Dylan [(0, 0.048669863), (1, 0.89384353), (2, 0.056287892)]
# Elton_John [(1, 0.010918136), (2, 0.9887022)]
# Led_Zeppeling [(0, 0.019153884), (1, 0.028511558), (2, 0.95207185)]
# Pink_Floyd [(2, 0.9956668)]
# Ramones [(3, 0.9990921)]
# The_Beatles [(1, 0.9992416)]
# The_Doors [(0, 0.101334356), (1, 0.62985957), (2, 0.2596207)]
